# %%
import sys
import csv
import os
import shutil
import pandas as pd
import numpy as np
import decimal
from pyneuroml import pynml
from pyneuroml.pynml import print_comment_v
from pyneuroml.lems import LEMSSimulation

import neuroml as nml
import neuroml.writers as writers
from neuroml.utils import validate_neuroml2
import random
random.seed(12345)
from neuroml.nml.nml import parse as nmlparse
import eden_tools
dir(eden_tools)

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
os.getcwd()
# Out:
# /opt/conda/lib/python3.7/site-packages/airspeed/__init__.py:505: FutureWarning: Possible nested set at position 8
#   KEYVALSEP = re.compile(r'[ \t]*:[[ \t]*(.*)$', re.S)
# '/home/jovyan/work/NeuroML_Examples/Rocher'

# %% [markdown]
# ## Choose which channel you want to examine
#
# Ugly but functional code ¯\\_(ツ)_/¯ to set the parameters how you like.
# The morphologies are read from Another_Cells folder, parameters adjusted and then saved to the Cells folder which is used for running the simulations.

# %%
path = os.getcwd()
Temp = 37
#net_id = "network_of_%s"%cell_id    
#net_doc = nml.NeuroMLDocument(id='net_'+str(cell_id))
results = []
channel_dict = dict(na_s_soma=0, kdr_soma=1, k_soma=2, cal_soma=3, BK_soma=4, cah_dend=5, kca_dend=6, h_dend=7, cacc_dend=8, na_axon=9, k_axon=10)

cellnames = open('cell_list.txt', 'r')
content = cellnames.read()
filenames = content.split("\n")
cellnames.close()
print(filenames)
# Out:
# ['C10', 'C11A', 'C15A', 'C16', 'C1A', 'C20A', 'C21A', 'C21B', 'C23', 'C25A', 'C25C', 'C28B', 'C31', 'C32B', 'C45A', 'C46A', 'C46B', 'C48', 'C49A', 'C49B', 'C49C', 'C4A', 'C50A', 'C50B', 'C51A', 'C51B', 'C51C', 'C51D', 'C6A']

# %%
for f in range(len(filenames)):
    cell_id = filenames[f]
    #os.remove('./pynmlNetworks/nml_'+cell_id+'.net.nml')
    #os.remove('./LEMSFILES/LEMS_'+str(sim_id)+'_'+str(cell_id)+'.xml')
    net_id = "network_of_%s"%cell_id    
    net_doc = nml.NeuroMLDocument(id='net_'+str(cell_id))

    #include cell file from ../Cells/
    cellfile = nml.IncludeType(href='../Cells/'+cell_id+'_scaled_exp_resample_5.cell.nml')
    net_doc.includes.append(cellfile)

    #create network
    net = nml.Network(id=net_id, type="networkWithTemperature", temperature=str(Temp)+"degC")
    net_doc.networks.append(net)

    #create population
    pop = nml.Population(id='population_of_%s'%cell_id,component=cell_id,type='populationList',size='1')
    net.populations.append(pop)

    loc = nml.Location(x='0',y='0',z='0')
    inst = nml.Instance(id='0',location=loc)
    pop.instances.append(inst)

    #include current clamp 
    t_delay = 0
    t_duration = 10
    Amp = '1.5nA'

    Iclamp0 = nml.PulseGenerator(id='iclamp0',delay=str(t_delay)+'ms',duration=str(t_duration)+'ms', amplitude=Amp)
    net_doc.pulse_generators.append(Iclamp0)

    Iclamp1 = nml.PulseGenerator(id='iclamp1',delay=str(t_delay)+'ms',duration=str(t_duration)+'ms', amplitude=Amp)
    net_doc.pulse_generators.append(Iclamp1)


    #add Iclamp to cell
    #input_list = nml.InputList(id='Iclamp0', component=Iclamp0.id, populations=pop.id)
    #input = nml.Input(id='0', target = "../%s/0/"%(pop.id)+str(cell_id), segmentId="0", destination="synapses")
    #input_list.input.append(input)
    #net.input_lists.append(input_list)

    input_list = nml.InputList(id='Iclamp1', component=Iclamp1.id, populations=pop.id)
    input = nml.Input(id='0', target = "../%s/0/"%(pop.id)+str(cell_id), segmentId="0", destination="synapses")
    input_list.input.append(input)
    input = nml.Input(id='1', target = "../%s/0/"%(pop.id)+str(cell_id), segmentId="0", destination="synapses")
    input_list.input.append(input)
    net.input_lists.append(input_list)



    #write the network file
    net_file_name = 'nml_'+cell_id+'.net.nml'
    writers.NeuroMLWriter.write(net_doc,net_file_name)
    shutil.move(path+'/'+str(net_file_name), path+'/pynmlNetworks')
    validate_neuroml2('./pynmlNetworks/nml_'+cell_id+'.net.nml')

    #redefine net and cell in case you don't run the above code segment
    sim_id = 'Test'
    length = 800
    step = 0.025

    #dend_channel = ["cah_dend/cah/r/q", "kca_dend/kca/z/q", "h_dend/h/n/q", "cacc_dend/cacc/m/q"]
    #axon_channel = ["na_axon/na_a/m/q", "na_axon/na_a/h/q", "k_axon/k/n/q"]
    soma_channel = ["na_s_soma/na_s/m/q", "na_s_soma/na_s/h/q", "kdr_soma/kdr/n/q", "k_soma/k/n/q", "cal_soma/cal/k/q", "cal_soma/cal/l/q", "BK_soma/BK/c/q"]
    recorded_segment = 0
    recorded_segment1 = 10
    recorded_segment2 = 69
    recorded_segment3 = 0
    recorded_variable1 = "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment1)+"/v"
    recorded_variable2 = "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment2)+"/v"
    recorded_variable3 = "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment3)+"/v"

    nmlfile = './pynmlNetworks/nml_'+cell_id+'.net.nml'  #include_neuroml2_file duplicates the path if you use path+ and does not find the file if you use ../
    LEMS = LEMSSimulation(sim_id, length , step , target = "network_of_%s"%cell_id)
    LEMS.include_neuroml2_file(nmlfile)
    LEMS.set_report_file('SimStat.txt')                                   # not necessary but out of interest to see EDEN vs NEURON 




    #disp_0 = 'Voltage'
    #LEMS.create_display(disp_0, 'Voltage trace', '-100', '70' )
    #LEMS.add_line_to_display(disp_0, recorded_segment, recorded_variable)

    #traces0 = 'voltage traces'
    #LEMS.create_output_file(traces0,"%s.v.dat"%sim_id)
    #LEMS.add_column_to_output_file(traces0, recorded_segment, recorded_variable)
    disp1 = 'Gates Dendrite'
    disp2 = 'Gates Axon'
    disp = 'Gates Soma'
    traces1 = 'Gate_file_dendrite'
    traces2 = 'Gate_file_axon'
    traces = 'Gate_file_soma'

    LEMS.create_display(disp, "Soma gate variables", "0", "1")
    LEMS.create_output_file(traces, "%s.Soma_gates.dat"%sim_id)

    #LEMS.create_display(disp1, "Dendrite gate variables", "0", "1")
    #LEMS.create_output_file(traces1, "%s.Dendrite_gates.dat"%sim_id)

    #LEMS.create_display(disp2, "Axon gate variables", "0", "1")
    #LEMS.create_output_file(traces2, "%s.Axon_gates.dat"%sim_id)

    #for i in range(len(dend_channel)):
        #disp1 = 'Gates Dendrite'
        #LEMS.create_display(disp1, "Dendrite gate variables", "0", "1")
     #   LEMS.add_line_to_display(disp1, recorded_segment1, "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment1)+"/biophys/membraneProperties/"+str(dend_channel[i]))

        #traces1 = 'Gate_file_dendrite'
        #LEMS.create_output_file(traces1, "%s.gates.dat"%sim_id)
     #   LEMS.add_column_to_output_file(traces1, recorded_segment1, "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment1)+"/biophys/membraneProperties/"+str(dend_channel[i]))

    #for i in range(len(axon_channel)):
        #disp2 = 'Gates Axon'
        #LEMS.create_display(disp1, "Dendrite gate variables", "0", "1")
      #  LEMS.add_line_to_display(disp2, recorded_segment2, "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment2)+"/biophys/membraneProperties/"+str(axon_channel[i]))

        #traces2 = 'Gate_file_axon'
        #LEMS.create_output_file(traces1, "%s.gates.dat"%sim_id)
     #   LEMS.add_column_to_output_file(traces2, recorded_segment2, "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment2)+"/biophys/membraneProperties/"+str(axon_channel[i]))   

    #for i in range(len(soma_channel)):
        #disp2 = 'Gates Axon'
        #LEMS.create_display(disp1, "Dendrite gate variables", "0", "1")
       # LEMS.add_line_to_display(disp, recorded_segment, "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment)+"/biophys/membraneProperties/"+str(soma_channel[i]))

        #traces2 = 'Gate_file_axon'
        #LEMS.create_output_file(traces1, "%s.gates.dat"%sim_id)
       # LEMS.add_column_to_output_file(traces, recorded_segment, "%s/0/"%(pop.id)+str(cell_id)+"/"+str(recorded_segment)+"/biophys/membraneProperties/"+str(soma_channel[i]))        



    disp4 = 'Soma Voltage'
    LEMS.create_display(disp4, "Dendrite trace", "-100", "70")
    LEMS.add_line_to_display(disp4, recorded_segment3, recorded_variable3)
    
    traces4 = 'Soma file'
    LEMS.create_output_file(traces4, "%s.vd.dat"%sim_id)
    LEMS.add_column_to_output_file(traces4, recorded_segment3, recorded_variable3)
    








    filename = 'LEMS_'+str(sim_id)+'_'+str(cell_id)+'.xml'
    LEMS.save_to_file(file_name = filename )

    #edit the wrong path generated by LEMS.include_neuroml2_file
    fin = open(path+'/'+str(filename), 'rt')
    data = fin.read()
    data = data.replace('<Include file="./pynmlNetworks/', '<Include file="../pynmlNetworks/')
    data = data.replace('ExpTime.nml', '../channels/ExpTime.nml')    # patch up for wrong path generated in network script
    fin.close()
    fin = open(path+'/'+str(filename), 'wt')
    fin.write(data)
    fin.close()

    shutil.move(path+'/'+str(filename), path+'/LEMSFILES')
# Out:
# Validating ./pynmlNetworks/nml_C10.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C10.xml
# Validating ./pynmlNetworks/nml_C11A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C11A.xml
# Validating ./pynmlNetworks/nml_C15A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C15A.xml
# Validating ./pynmlNetworks/nml_C16.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C16.xml
# Validating ./pynmlNetworks/nml_C1A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C1A.xml
# Validating ./pynmlNetworks/nml_C20A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C20A.xml
# Validating ./pynmlNetworks/nml_C21A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C21A.xml
# Validating ./pynmlNetworks/nml_C21B.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C21B.xml
# Validating ./pynmlNetworks/nml_C23.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C23.xml
# Validating ./pynmlNetworks/nml_C25A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C25A.xml
# Validating ./pynmlNetworks/nml_C25C.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C25C.xml
# Validating ./pynmlNetworks/nml_C28B.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C28B.xml
# Validating ./pynmlNetworks/nml_C31.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C31.xml
# Validating ./pynmlNetworks/nml_C32B.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C32B.xml
# Validating ./pynmlNetworks/nml_C45A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C45A.xml
# Validating ./pynmlNetworks/nml_C46A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C46A.xml
# Validating ./pynmlNetworks/nml_C46B.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C46B.xml
# Validating ./pynmlNetworks/nml_C48.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C48.xml
# Validating ./pynmlNetworks/nml_C49A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C49A.xml
# Validating ./pynmlNetworks/nml_C49B.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C49B.xml
# Validating ./pynmlNetworks/nml_C49C.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C49C.xml
# Validating ./pynmlNetworks/nml_C4A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C4A.xml
# Validating ./pynmlNetworks/nml_C50A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C50A.xml
# Validating ./pynmlNetworks/nml_C50B.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C50B.xml
# Validating ./pynmlNetworks/nml_C51A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C51A.xml
# Validating ./pynmlNetworks/nml_C51B.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C51B.xml
# Validating ./pynmlNetworks/nml_C51C.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C51C.xml
# Validating ./pynmlNetworks/nml_C51D.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C51D.xml
# Validating ./pynmlNetworks/nml_C6A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# pyNeuroML >>> Written LEMS Simulation Test to file: LEMS_Test_C6A.xml

# %%
results = []
#parameter = []

for g in range(len(filenames)):
    cell_id = filenames[g]
    filename = 'LEMS_'+str(sim_id)+'_'+str(cell_id)+'.xml'
    LEMS_file = f'LEMSFILES/{filename}'
    #doc = nmlparse('Another_Cells/'+cell_id+'_scaled_exp_resample_5.cell.nml')
    #doc.cells[0].biophysical_properties.membrane_properties.channel_densities[channel_dict[chosen_channel]].cond_density = str(parameter[g])+' mS_per_cm2'
    #writers.NeuroMLWriter.write(doc, 'Cells/'+cell_id+'_scaled_exp_resample_5.cell.nml')

 

    #out_dir = path+'\Simulation result'
    out_dir,rel_filename = os.path.split(LEMS_file)
    print(out_dir)
    print(rel_filename)



    print(f'You are running a simulation of {LEMS_file} and saving the results to {out_dir}\n')

    #results = {}
    #results = pynml.run_lems_with_jneuroml_neuron(
    #        LEMS_file, verbose=False, nogui=True, load_saved_data=True, exec_in_dir= out_dir,
    #        max_memory='1000M')


    #results_Eden = eden_tools.runEden( LEMS_file, verbose=True )
    results_Neuron = eden_tools.runNeuron( LEMS_file, verbose=True )
    results.append(dict(results_Neuron))
# Out:
# LEMSFILES
# LEMS_Test_C10.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C10.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C10.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C10.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 3.20 seconds
# LEMSFILES
# LEMS_Test_C11A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C11A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C11A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C11A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.70 seconds
# LEMSFILES
# LEMS_Test_C15A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C15A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C15A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C15A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.83 seconds
# LEMSFILES
# LEMS_Test_C16.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C16.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C16.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C16.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.16 seconds
# LEMSFILES
# LEMS_Test_C1A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C1A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C1A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C1A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.21 seconds
# LEMSFILES
# LEMS_Test_C20A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C20A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C20A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C20A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.21 seconds
# LEMSFILES
# LEMS_Test_C21A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C21A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C21A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C21A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.39 seconds
# LEMSFILES
# LEMS_Test_C21B.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C21B.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C21B.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C21B.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.59 seconds
# LEMSFILES
# LEMS_Test_C23.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C23.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C23.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C23.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 3.06 seconds
# LEMSFILES
# LEMS_Test_C25A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C25A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C25A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C25A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 1.99 seconds
# LEMSFILES
# LEMS_Test_C25C.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C25C.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C25C.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C25C.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.16 seconds
# LEMSFILES
# LEMS_Test_C28B.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C28B.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C28B.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C28B.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.19 seconds
# LEMSFILES
# LEMS_Test_C31.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C31.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C31.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C31.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.51 seconds
# LEMSFILES
# LEMS_Test_C32B.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C32B.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C32B.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C32B.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.25 seconds
# LEMSFILES
# LEMS_Test_C45A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C45A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C45A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C45A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.27 seconds
# LEMSFILES
# LEMS_Test_C46A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C46A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C46A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C46A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.12 seconds
# LEMSFILES
# LEMS_Test_C46B.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C46B.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C46B.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C46B.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.20 seconds
# LEMSFILES
# LEMS_Test_C48.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C48.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C48.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C48.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.17 seconds
# LEMSFILES
# LEMS_Test_C49A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C49A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C49A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C49A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.25 seconds
# LEMSFILES
# LEMS_Test_C49B.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C49B.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C49B.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C49B.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.39 seconds
# LEMSFILES
# LEMS_Test_C49C.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C49C.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C49C.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C49C.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.20 seconds
# LEMSFILES
# LEMS_Test_C4A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C4A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C4A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C4A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.56 seconds
# LEMSFILES
# LEMS_Test_C50A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C50A.xml and saving the results to LEMSFILES
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C50A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C50A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.15 seconds
# LEMSFILES
# LEMS_Test_C50B.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C50B.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C50B.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C50B.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.30 seconds
# LEMSFILES
# LEMS_Test_C51A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C51A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C51A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C51A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.11 seconds
# LEMSFILES
# LEMS_Test_C51B.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C51B.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C51B.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C51B.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.37 seconds
# LEMSFILES
# LEMS_Test_C51C.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C51C.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C51C.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C51C.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.56 seconds
# LEMSFILES
# LEMS_Test_C51D.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C51D.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C51D.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C51D.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.20 seconds
# LEMSFILES
# LEMS_Test_C6A.xml
# You are running a simulation of LEMSFILES/LEMS_Test_C6A.xml and saving the results to LEMSFILES
#
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Test_C6A.xml (/home/jovyan/work/NeuroML_Examples/Rocher/LEMSFILES/LEMS_Test_C6A.xml), base_dir: LEMSFILES, cwd: /home/jovyan/work/NeuroML_Examples/Rocher
# Ran jNeuroML_NEURON in 2.86 seconds

# %%
plt.xlabel('Time (s)')
plt.ylabel('Values')
plt.grid(True)

# plt.gca().clear()

for i in range(len(results)):

    for key in results[i]:
        results_Neuron = results[i]
        if key == 't':
            # no need to plot sim time against sim time
            continue
        plt.plot(results_Neuron['t'],results_Neuron[key], label=""+key)

    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0))
    plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   if isinstance(obj, collections.Iterator):
# /opt/conda/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2366: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   return list(data) if isinstance(data, collections.MappingView) else data

# %%
for g in range(len(results)):
    results_Neuron = results[g]
    cell_id = filenames[g]
    plt.figure(5, figsize=(15,6))
    plt.plot(results_Neuron['t'], results_Neuron['population_of_'+str(cell_id)+'/0/'+str(cell_id)+'/0/v'], label = "v soma"+str(g))
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0))
plt.show()

# %%
os.remove(nmlfile)
os.remove(LEMS_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-66dc88cb2925> in <module>
# ----> 1 os.remove(nmlfile)
#       2 os.remove(LEMS_file)
#
# NameError: name 'nmlfile' is not defined

# %%
g_cal = 10 *10^-12
k = results_Neuron['population_of_C51A/0/C51A/0/biophys/membraneProperties/cal_soma/cal/k/q']
l = results_Neuron['population_of_C51A/0/C51A/0/biophys/membraneProperties/cal_soma/cal/l/q']
#Ical = k*k*k*l
Ical = [a * b for a, b in zip(k, l)]

# %%
results_Neuron = results[1]
cell_id = filenames[1]
plt.figure(5, figsize=(15,6))
plt.plot(results_Neuron['t'], results_Neuron['population_of_'+str(cell_id)+'/0/'+str(cell_id)+'/0/v'], label = "v soma"+str(g))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0))
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-a3864589813d> in <module>
#       3 X = [np.sin(g), g]
#       4 Y = [np.sin(g), g]
# ----> 5 Axes3D.plot_surface(X,Y,Z)
#
# TypeError: plot_surface() missing 1 required positional argument: 'Z'

# %%
# Out:
# 29
