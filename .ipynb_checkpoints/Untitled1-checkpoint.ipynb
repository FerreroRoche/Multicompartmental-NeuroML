# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
import pandas as pd
from IPython.display import display

x = []
y = []
z = []

with open('results.dat.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=';')
    for row in plots:
        x.append((row[0]))
        y.append(float(row[1]))
        z.append(float(row[2]))

# %%
x = np.transpose(x)
y = np.transpose(y)
z = np.transpose(z)
j = [0 , 5 , 3 , 8 , 9 , 5 , 3 , 1 , 3 , 5 ]
t = np.linspace(0.0,3.0,num=120001)

# %%
plt.plot(t,z,t,y)
# Out:
# [<matplotlib.lines.Line2D at 0x12ece7755c8>,
#  <matplotlib.lines.Line2D at 0x12ece608bc8>]

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()
